# %% [markdown]
# # ETL Project
#
# ## Scrub down the olympic data set to limited scope.

# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql
import sqlite3 as sl

# %%
# Read in Olympic data

olympic_history = "./raw_olympic_data/athlete_events.csv"
o_history_df = pd.read_csv(olympic_history)
o_history_df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
# Read in olympic region data

noc_regions = "./raw_olympic_data/noc_regions.csv"
regions_df = pd.read_csv(noc_regions)
regions_df.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
# drop notes column

reg_cols = ["NOC", "region"]
reg_cat_df = regions_df[reg_cols]
reg_cat_df.head()
# Out:
#    NOC       region
# 0  AFG  Afghanistan
# 1  AHO      Curacao
# 2  ALB      Albania
# 3  ALG      Algeria
# 4  AND      Andorra

# %%
# Check for null fields

reg_cat_df.count()
# Out:
# NOC       230
# region    227
# dtype: int64

# %%
# Drop all null fields from regions df

no_null_reg_cat_df = reg_cat_df.dropna(how='any')
no_null_reg_cat_df.head()

no_null_reg_cat_df.count()
# Out:
# NOC       227
# region    227
# dtype: int64

# %%
noc_df = no_null_reg_cat_df
print(len(noc_df))
noc_df.head()
# Out:
# 227
#    NOC       region
# 0  AFG  Afghanistan
# 1  AHO      Curacao
# 2  ALB      Albania
# 3  ALG      Algeria
# 4  AND      Andorra

# %%
# select columns for olympic events df

cols = ["Team","Games", "Season", "City", "Medal", "Sport", "Event", 'NOC']
olympic_cat_df = o_history_df[cols]
olympic_cat_df.head()
# Out:
#              Team        Games  Season       City Medal          Sport  \
# 0           China  1992 Summer  Summer  Barcelona   NaN     Basketball
# 1           China  2012 Summer  Summer     London   NaN           Judo
# 2         Denmark  1920 Summer  Summer  Antwerpen   NaN       Football
# 3  Denmark/Sweden  1900 Summer  Summer      Paris  Gold     Tug-Of-War
# 4     Netherlands  1988 Winter  Winter    Calgary   NaN  Speed Skating
#
#                               Event  NOC
# 0       Basketball Men's Basketball  CHN
# 1      Judo Men's Extra-Lightweight  CHN
# 2           Football Men's Football  DEN
# 3       Tug-Of-War Men's Tug-Of-War  DEN
# 4  Speed Skating Women's 500 metres  NED

# %%
olympic_cat_df.count()
# Out:
# Team      271116
# Games     271116
# Season    271116
# City      271116
# Medal      39783
# Sport     271116
# Event     271116
# NOC       271116
# dtype: int64

# %%
# Drop all null fields from  olympic events df

no_null_olympic_cat_df = olympic_cat_df.dropna(how='any')
no_null_olympic_cat_df.head()
# Out:
#               Team        Games  Season       City   Medal       Sport  \
# 3   Denmark/Sweden  1900 Summer  Summer      Paris    Gold  Tug-Of-War
# 37         Finland  1920 Summer  Summer  Antwerpen  Bronze    Swimming
# 38         Finland  1920 Summer  Summer  Antwerpen  Bronze    Swimming
# 40         Finland  2014 Winter  Winter      Sochi  Bronze  Ice Hockey
# 41         Finland  1948 Summer  Summer     London  Bronze  Gymnastics
#
#                                      Event  NOC
# 3              Tug-Of-War Men's Tug-Of-War  DEN
# 37  Swimming Men's 200 metres Breaststroke  FIN
# 38  Swimming Men's 400 metres Breaststroke  FIN
# 40             Ice Hockey Men's Ice Hockey  FIN
# 41  Gymnastics Men's Individual All-Around  FIN

# %%
# summary of medal counts

no_null_olympic_cat_df["Medal"].value_counts()
# Out:
# Gold      13372
# Bronze    13295
# Silver    13116
# Name: Medal, dtype: int64

# %%
# Define final table for olympic data

new_data_df = no_null_olympic_cat_df
new_data_df.head()
# Out:
#               Team        Games  Season       City   Medal       Sport  \
# 3   Denmark/Sweden  1900 Summer  Summer      Paris    Gold  Tug-Of-War
# 37         Finland  1920 Summer  Summer  Antwerpen  Bronze    Swimming
# 38         Finland  1920 Summer  Summer  Antwerpen  Bronze    Swimming
# 40         Finland  2014 Winter  Winter      Sochi  Bronze  Ice Hockey
# 41         Finland  1948 Summer  Summer     London  Bronze  Gymnastics
#
#                                      Event  NOC
# 3              Tug-Of-War Men's Tug-Of-War  DEN
# 37  Swimming Men's 200 metres Breaststroke  FIN
# 38  Swimming Men's 400 metres Breaststroke  FIN
# 40             Ice Hockey Men's Ice Hockey  FIN
# 41  Gymnastics Men's Individual All-Around  FIN

# %%
# List all sports in olympic event df

new_data_df["Sport"].unique()
# Out:
# array(['Tug-Of-War', 'Swimming', 'Ice Hockey', 'Gymnastics',
#        'Alpine Skiing', 'Handball', 'Hockey', 'Rowing', 'Football',
#        'Speed Skating', 'Sailing', 'Cycling', 'Fencing', 'Taekwondo',
#        'Athletics', 'Canoeing', 'Water Polo', 'Wrestling',
#        'Modern Pentathlon', 'Figure Skating', 'Golf', 'Softball',
#        'Boxing', 'Basketball', 'Nordic Combined', 'Diving', 'Baseball',
#        'Volleyball', 'Cross Country Skiing', 'Bobsleigh', 'Curling',
#        'Shooting', 'Judo', 'Equestrianism', 'Tennis', 'Rugby Sevens',
#        'Rhythmic Gymnastics', 'Weightlifting', 'Badminton',
#        'Beach Volleyball', 'Ski Jumping', 'Rugby',
#        'Short Track Speed Skating', 'Biathlon', 'Lacrosse',
#        'Synchronized Swimming', 'Archery', 'Freestyle Skiing',
#        'Triathlon', 'Polo', 'Luge', 'Table Tennis', 'Snowboarding',
#        'Cricket', 'Skeleton', 'Racquets', 'Military Ski Patrol',
#        'Croquet', 'Art Competitions', 'Roque', 'Alpinism', 'Trampolining',
#        'Basque Pelota', 'Motorboating', 'Jeu De Paume', 'Aeronautics'],
#       dtype=object)

# %%
# select sports of interest

sports = ["Swimming", "Speed Skating"]
new_data_df = new_data_df.loc[new_data_df["Sport"].isin(sports)]

# %%
# Clean column name formats

new_data_df.columns = ['team', 'games', 'seasons', 'city', 'medal', 'sport', 'event', 'NOC']
new_data_df.head()
# Out:
#         team        games seasons          city   medal          sport  \
# 37   Finland  1920 Summer  Summer     Antwerpen  Bronze       Swimming
# 38   Finland  1920 Summer  Summer     Antwerpen  Bronze       Swimming
# 110   Norway  1952 Winter  Winter          Oslo  Bronze  Speed Skating
# 113   Norway  1960 Winter  Winter  Squaw Valley    Gold  Speed Skating
# 210  Hungary  1936 Summer  Summer        Berlin  Bronze       Swimming
#
#                                              event  NOC
# 37          Swimming Men's 200 metres Breaststroke  FIN
# 38          Swimming Men's 400 metres Breaststroke  FIN
# 110               Speed Skating Men's 1,500 metres  NOR
# 113               Speed Skating Men's 1,500 metres  NOR
# 210  Swimming Men's 4 x 200 metres Freestyle Relay  HUN

# %%
# write to sql lite table

conn = sl.connect('olympic_db.sqlite')

new_data_df.to_sql('tab', conn, if_exists='replace', index=False)

# %%
noc_df.to_sql('noc', conn, if_exists='replace', index=False)
